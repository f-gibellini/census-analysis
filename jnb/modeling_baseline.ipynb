# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from catboost import CatBoostClassifier
from sklearn.model_selection import train_test_split

import pandas as pd
import os
import sys

if not os.path.abspath(os.pardir) in sys.path:
    sys.path.append(os.path.abspath(os.pardir))

from src.data_reader import read_data

# %%
DATA_PATH = '../data/'
MODELS_PATH = '../models/'

TRAIN_FNAME = 'census_income_learn.csv'
TEST_FNAME = 'census_income_test.csv'
METADATA_FNAME = 'census_income_metadata.txt'
MODELS_LOG_FNAME = 'experiments_log.csv'

COLORS = ['#4DC9C3', '#221C35', '#FCCD20', '#20C3EF', '#00B257', '#FF7700']

TARGET_NAME = 'income'

N_JOBS = 6
GPU = True

# %%
class FeaturesProcessor():

    def __init__(self, cat_encoding = 'OHE', encoders = None):

        self.cat_encoding = cat_encoding
        self.encoders = encoders


    def _make_encoder(self, df, col):

        mode = self.cat_encoding
        
        if mode == 'OHE':
            encoder = OneHotEncoder(sparse_output=False, handle_unknown='ignore')
        else:
            encoder = LabelEncoder()
        
        encoder.fit(df[[col]])
        self.encoders[col] = encoder        
    
    def transform_cat_features(self, df):

        mode = self.cat_encoding
        
        if mode not in ['OHE', 'LE']:
            print(f'Unsupported mode {mode} defaulting to One Hot Encoding')
            mode = 'OHE'

        if self.encoders is None:
            print('Encoders not found, creating new encoders')
            self.encoders = {}
        else:
            print('Encoders were found, using existing encoders')
        
        encoded_df = pd.DataFrame()
        
        for col in df.columns:
            #if column is object (not numerical)
            if (train_df[col].dtype == 'O') and (col != TARGET_NAME):

                if not (col in self.encoders.keys()):
                    self._make_encoder(df, col)
                
                encoder = self.encoders[col]

                encoded_features = encoder.transform(df[[col]])
                if mode == 'OHE':
                    feat_names = [f"{col}_{cat}" for cat in encoder.categories_[0]]
                else:
                    feat_names = [col]
                    
                encoded_df = pd.concat([encoded_df,
                                        pd.DataFrame(encoded_features, columns=feat_names)], axis=1)
            elif (train_df[col].dtype != 'O') and (col != TARGET_NAME):
                encoded_df[col] = df[col]
            
            else: #target column
                encoder = LabelEncoder()
        
                encoder.fit(df[[col]])
                self.encoders[col] = encoder 
                encoded_df[col] = encoder.transform(df[[col]])
                
        return encoded_df, self.encoders

# %%
train_df = read_data(DATA_PATH + TRAIN_FNAME, DATA_PATH + METADATA_FNAME)
test_df = read_data(DATA_PATH + TEST_FNAME, DATA_PATH + METADATA_FNAME)
test_df.shape, train_df.shape
# Out:
# Read input data file ../data/census_income_learn.csv
# /home/francesco/dku-iw/src/data_reader.py:97: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x:x.lower().strip() if (isinstance(x, str)) else (x))
# Read metadata file ../data/census_income_metadata.txt
# Couldnt parse line
# Mapped columns
# /home/francesco/dku-iw/src/data_reader.py:118: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x:np.nan if (isinstance(x, str) and (('not in universe' in x) or ('?' in x) or (x == 'na')
# Read input data file ../data/census_income_test.csv
# /home/francesco/dku-iw/src/data_reader.py:97: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x:x.lower().strip() if (isinstance(x, str)) else (x))
# Read metadata file ../data/census_income_metadata.txt
# Couldnt parse line
# Mapped columns
# /home/francesco/dku-iw/src/data_reader.py:118: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   df = df.applymap(lambda x:np.nan if (isinstance(x, str) and (('not in universe' in x) or ('?' in x) or (x == 'na')
# ((99762, 42), (199523, 42))

# %%
fprocessor = FeaturesProcessor('OHE')

encoded_train_df, encoders = fprocessor.transform_cat_features(train_df)
encoded_test_df, encoders = fprocessor.transform_cat_features(test_df)

encoded_train_df, encoded_val_df = train_test_split(encoded_train_df, test_size=0.1, random_state=42)


encoded_train_df.shape, encoded_val_df.shape, encoded_test_df.shape
# Out:
# Encoders not found, creating new encoders
# /home/francesco/.local/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/francesco/.local/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# Encoders were found, using existing encoders
# /home/francesco/.local/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:93: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /home/francesco/.local/lib/python3.10/site-packages/sklearn/preprocessing/_label.py:129: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, dtype=self.classes_.dtype, warn=True)
# ((179570, 405), (19953, 405), (99762, 405))

# %%
from sklearn.metrics import precision_score, recall_score, f1_score, confusion_matrix

def evaluate_model(y_true, y_pred):

    precision = precision_score(y_true, y_pred)
    recall = recall_score(y_true, y_pred)
    f1 = f1_score(y_true, y_pred)
    conf_matrix = confusion_matrix(y_true, y_pred)

    return [f1, precision, recall, str(conf_matrix)]


def get_model_string(model):
    model_name = model.__class__.__name__
    params = model.get_params()
    param_str = ",".join(f"{k}={v}" for k, v in params.items())
    return f"{model_name}({param_str})"

def log_model(exp_name, fname, metrics, col_names = ['expriment_name', 'f1-score', 'precision', 'recall', 'conf_matrix']):

    #if log file exists, append
    if os.path.isfile(fname):
        existing_logs = pd.read_csv(fname)
        pd.concat([existing_logs,
                  pd.DataFrame([[exp_name, *metrics]], columns = existing_logs.columns)]).to_csv(fname, index = False)

    #log file doesnt exist yet
    else:
        pd.DataFrame([[exp_name, *metrics]], columns = col_names).to_csv(fname, index = False)

# %%
#feature names
feat_names = [col for col in encoded_train_df.columns if (col != TARGET_NAME)]



models = [ LogisticRegression(C=1.0, class_weight='balanced', max_iter=200, n_jobs = N_JOBS), #strong regularization, class balancing
          LogisticRegression(C=1.0, class_weight='balanced', max_iter=500, n_jobs = N_JOBS), 
          LogisticRegression(C=1.0, class_weight='balanced', max_iter=1000, n_jobs = N_JOBS), 
          LogisticRegression(C=0.1, class_weight='balanced', max_iter=200, n_jobs = N_JOBS), #weak regularization, class balancing
          LogisticRegression(C=0.1, class_weight='balanced', max_iter=500, n_jobs = N_JOBS), 
          LogisticRegression(C=0.1, class_weight='balanced', max_iter=1000, n_jobs = N_JOBS), 

          DecisionTreeClassifier(max_depth=4, class_weight='balanced'),
          DecisionTreeClassifier(max_depth=7, class_weight='balanced'),
          DecisionTreeClassifier(max_depth=10, class_weight='balanced'),
          DecisionTreeClassifier(max_depth=13, class_weight='balanced'),

          RandomForestClassifier(n_estimators=500, max_depth=3, max_features=0.3, n_jobs=N_JOBS), #try not very deep trees
          RandomForestClassifier(n_estimators=1000, max_depth=3, max_features=0.3, n_jobs=N_JOBS),
          RandomForestClassifier(n_estimators=1500, max_depth=3, max_features=0.3, n_jobs=N_JOBS),
          RandomForestClassifier(n_estimators=500, max_depth=6, n_jobs=N_JOBS), #try deeper trees
          RandomForestClassifier(n_estimators=1000, max_depth=6, n_jobs=N_JOBS),
          RandomForestClassifier(n_estimators=1500, max_depth=6, n_jobs=N_JOBS),
    
          CatBoostClassifier(iterations = 500, task_type = 'GPU' if GPU else 'CPU'),
          CatBoostClassifier(iterations = 1000, task_type = 'GPU' if GPU else 'CPU'),
          CatBoostClassifier(iterations = 1500, task_type = 'GPU' if GPU else 'CPU'),
          CatBoostClassifier(iterations = 2000, task_type = 'GPU' if GPU else 'CPU'),
         
         
         ]

exp_name_base = 'baselines_{}'
for model in models:

    model.fit(encoded_train_df[feat_names], encoded_train_df[TARGET_NAME])

    metrics = evaluate_model(model.predict(encoded_val_df[feat_names]), encoded_val_df[TARGET_NAME])
    model_name = get_model_string(model)
    
    log_model(exp_name_base.format(model_name),
             MODELS_PATH + MODELS_LOG_FNAME,
             metrics)

    print(model_name)
    print(metrics)
    print()
# Out:
# /home/francesco/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=1.0,class_weight=balanced,dual=False,fit_intercept=True,intercept_scaling=1,l1_ratio=None,max_iter=200,multi_class=deprecated,n_jobs=6,penalty=l2,random_state=None,solver=lbfgs,tol=0.0001,verbose=0,warm_start=False)
# [0.36731891520768967, 0.8756137479541735, 0.23240660295395307, '[[15197   152]\n [ 3534  1070]]']
# /home/francesco/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=1.0,class_weight=balanced,dual=False,fit_intercept=True,intercept_scaling=1,l1_ratio=None,max_iter=500,multi_class=deprecated,n_jobs=6,penalty=l2,random_state=None,solver=lbfgs,tol=0.0001,verbose=0,warm_start=False)
# [0.3863072011351543, 0.8911620294599017, 0.24660326086956522, '[[15404   133]\n [ 3327  1089]]']
# /home/francesco/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=1.0,class_weight=balanced,dual=False,fit_intercept=True,intercept_scaling=1,l1_ratio=None,max_iter=1000,multi_class=deprecated,n_jobs=6,penalty=l2,random_state=None,solver=lbfgs,tol=0.0001,verbose=0,warm_start=False)
# [0.39985052316890884, 0.8756137479541735, 0.25907990314769974, '[[15671   152]\n [ 3060  1070]]']
# /home/francesco/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=0.1,class_weight=balanced,dual=False,fit_intercept=True,intercept_scaling=1,l1_ratio=None,max_iter=200,multi_class=deprecated,n_jobs=6,penalty=l2,random_state=None,solver=lbfgs,tol=0.0001,verbose=0,warm_start=False)
# [0.3467007509186771, 0.8878887070376432, 0.21540599563232082, '[[14779   137]\n [ 3952  1085]]']
# /home/francesco/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=0.1,class_weight=balanced,dual=False,fit_intercept=True,intercept_scaling=1,l1_ratio=None,max_iter=500,multi_class=deprecated,n_jobs=6,penalty=l2,random_state=None,solver=lbfgs,tol=0.0001,verbose=0,warm_start=False)
# [0.38637174455940065, 0.886252045826514, 0.24703467153284672, '[[15430   139]\n [ 3301  1083]]']
# /home/francesco/.local/lib/python3.10/site-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(C=0.1,class_weight=balanced,dual=False,fit_intercept=True,intercept_scaling=1,l1_ratio=None,max_iter=1000,multi_class=deprecated,n_jobs=6,penalty=l2,random_state=None,solver=lbfgs,tol=0.0001,verbose=0,warm_start=False)
# [0.39626099706744866, 0.8846153846153846, 0.2553141237600378, '[[15578   141]\n [ 3153  1081]]']
#
# DecisionTreeClassifier(ccp_alpha=0.0,class_weight=balanced,criterion=gini,max_depth=4,max_features=None,max_leaf_nodes=None,min_impurity_decrease=0.0,min_samples_leaf=1,min_samples_split=2,min_weight_fraction_leaf=0.0,monotonic_cst=None,random_state=None,splitter=best)
# [0.34113816095518684, 0.900163666121113, 0.21044576238760282, '[[14604   122]\n [ 4127  1100]]']
#
# DecisionTreeClassifier(ccp_alpha=0.0,class_weight=balanced,criterion=gini,max_depth=7,max_features=None,max_leaf_nodes=None,min_impurity_decrease=0.0,min_samples_leaf=1,min_samples_split=2,min_weight_fraction_leaf=0.0,monotonic_cst=None,random_state=None,splitter=best)
# [0.4104716227018385, 0.8404255319148937, 0.2715494447382337, '[[15976   195]\n [ 2755  1027]]']
#
# DecisionTreeClassifier(ccp_alpha=0.0,class_weight=balanced,criterion=gini,max_depth=10,max_features=None,max_leaf_nodes=None,min_impurity_decrease=0.0,min_samples_leaf=1,min_samples_split=2,min_weight_fraction_leaf=0.0,monotonic_cst=None,random_state=None,splitter=best)
# [0.41153546375681993, 0.8641571194762684, 0.270076726342711, '[[15877   166]\n [ 2854  1056]]']
#
# DecisionTreeClassifier(ccp_alpha=0.0,class_weight=balanced,criterion=gini,max_depth=13,max_features=None,max_leaf_nodes=None,min_impurity_decrease=0.0,min_samples_leaf=1,min_samples_split=2,min_weight_fraction_leaf=0.0,monotonic_cst=None,random_state=None,splitter=best)
# [0.41742654508611954, 0.8428805237315876, 0.2774037166711554, '[[16048   192]\n [ 2683  1030]]']
#
# RandomForestClassifier(bootstrap=True,ccp_alpha=0.0,class_weight=None,criterion=gini,max_depth=3,max_features=0.3,max_leaf_nodes=None,max_samples=None,min_impurity_decrease=0.0,min_samples_leaf=1,min_samples_split=2,min_weight_fraction_leaf=0.0,monotonic_cst=None,n_estimators=500,n_jobs=6,oob_score=False,random_state=None,verbose=0,warm_start=False)
# [0.21362007168458783, 0.12193126022913257, 0.861271676300578, '[[18707  1073]\n [   24   149]]']
#
# RandomForestClassifier(bootstrap=True,ccp_alpha=0.0,class_weight=None,criterion=gini,max_depth=3,max_features=0.3,max_leaf_nodes=None,max_samples=None,min_impurity_decrease=0.0,min_samples_leaf=1,min_samples_split=2,min_weight_fraction_leaf=0.0,monotonic_cst=None,n_estimators=1000,n_jobs=6,oob_score=False,random_state=None,verbose=0,warm_start=False)
# [0.20505415162454874, 0.11620294599018004, 0.8711656441717791, '[[18710  1080]\n [   21   142]]']
#
# RandomForestClassifier(bootstrap=True,ccp_alpha=0.0,class_weight=None,criterion=gini,max_depth=3,max_features=0.3,max_leaf_nodes=None,max_samples=None,min_impurity_decrease=0.0,min_samples_leaf=1,min_samples_split=2,min_weight_fraction_leaf=0.0,monotonic_cst=None,n_estimators=1500,n_jobs=6,oob_score=False,random_state=None,verbose=0,warm_start=False)
# [0.22032693674484718, 0.12684124386252046, 0.8378378378378378, '[[18701  1067]\n [   30   155]]']
#
# RandomForestClassifier(bootstrap=True,ccp_alpha=0.0,class_weight=None,criterion=gini,max_depth=6,max_features=sqrt,max_leaf_nodes=None,max_samples=None,min_impurity_decrease=0.0,min_samples_leaf=1,min_samples_split=2,min_weight_fraction_leaf=0.0,monotonic_cst=None,n_estimators=500,n_jobs=6,oob_score=False,random_state=None,verbose=0,warm_start=False)
# [0.008149959250203748, 0.004091653027823241, 1.0, '[[18731  1217]\n [    0     5]]']
#
# RandomForestClassifier(bootstrap=True,ccp_alpha=0.0,class_weight=None,criterion=gini,max_depth=6,max_features=sqrt,max_leaf_nodes=None,max_samples=None,min_impurity_decrease=0.0,min_samples_leaf=1,min_samples_split=2,min_weight_fraction_leaf=0.0,monotonic_cst=None,n_estimators=1000,n_jobs=6,oob_score=False,random_state=None,verbose=0,warm_start=False)
# [0.019448946515397084, 0.009819967266775777, 1.0, '[[18731  1210]\n [    0    12]]']
#
# RandomForestClassifier(bootstrap=True,ccp_alpha=0.0,class_weight=None,criterion=gini,max_depth=6,max_features=sqrt,max_leaf_nodes=None,max_samples=None,min_impurity_decrease=0.0,min_samples_leaf=1,min_samples_split=2,min_weight_fraction_leaf=0.0,monotonic_cst=None,n_estimators=1500,n_jobs=6,oob_score=False,random_state=None,verbose=0,warm_start=False)
# [0.019448946515397084, 0.009819967266775777, 1.0, '[[18731  1210]\n [    0    12]]']
#
# Learning rate set to 0.047153
# 0:	learn: 0.6045701	total: 6.32ms	remaining: 3.15s
# 1:	learn: 0.5199437	total: 12.2ms	remaining: 3.03s
# 2:	learn: 0.4660031	total: 18ms	remaining: 2.98s
# 3:	learn: 0.4242375	total: 23.7ms	remaining: 2.94s
# 4:	learn: 0.3822963	total: 29.3ms	remaining: 2.9s
# 5:	learn: 0.3429763	total: 35ms	remaining: 2.88s
# 6:	learn: 0.3162971	total: 40.7ms	remaining: 2.87s
# 7:	learn: 0.2862809	total: 46.6ms	remaining: 2.86s
# 8:	learn: 0.2692556	total: 52.7ms	remaining: 2.87s
# 9:	learn: 0.2501882	total: 59ms	remaining: 2.89s
# 10:	learn: 0.2336337	total: 64.9ms	remaining: 2.88s
# 11:	learn: 0.2216281	total: 70.9ms	remaining: 2.88s
# 12:	learn: 0.2105804	total: 76.9ms	remaining: 2.88s
# 13:	learn: 0.2002589	total: 82.8ms	remaining: 2.88s
# 14:	learn: 0.1925664	total: 88.9ms	remaining: 2.87s
# 15:	learn: 0.1870108	total: 94.7ms	remaining: 2.86s
# 16:	learn: 0.1811571	total: 101ms	remaining: 2.86s
# 17:	learn: 0.1755921	total: 107ms	remaining: 2.85s
# 18:	learn: 0.1716239	total: 112ms	remaining: 2.85s
# 19:	learn: 0.1669707	total: 119ms	remaining: 2.85s
# 20:	learn: 0.1645743	total: 126ms	remaining: 2.88s
# 21:	learn: 0.1621772	total: 132ms	remaining: 2.87s
# 22:	learn: 0.1585949	total: 139ms	remaining: 2.89s
# 23:	learn: 0.1562347	total: 145ms	remaining: 2.88s
# 24:	learn: 0.1541212	total: 152ms	remaining: 2.88s
# 25:	learn: 0.1527407	total: 158ms	remaining: 2.88s
# 26:	learn: 0.1511533	total: 164ms	remaining: 2.87s
# 27:	learn: 0.1489438	total: 170ms	remaining: 2.87s
# 28:	learn: 0.1475569	total: 176ms	remaining: 2.86s
# 29:	learn: 0.1465036	total: 183ms	remaining: 2.87s
# 30:	learn: 0.1449485	total: 189ms	remaining: 2.86s
# 173:	learn: 0.1167600	total: 1.05s	remaining: 1.96s
# 174:	learn: 0.1167140	total: 1.05s	remaining: 1.96s
# 175:	learn: 0.1166601	total: 1.06s	remaining: 1.95s
# 176:	learn: 0.1166350	total: 1.06s	remaining: 1.94s
# 177:	learn: 0.1165761	total: 1.07s	remaining: 1.94s
# 178:	learn: 0.1165310	total: 1.07s	remaining: 1.93s
# 179:	learn: 0.1164722	total: 1.08s	remaining: 1.92s
# 180:	learn: 0.1164409	total: 1.09s	remaining: 1.92s
# 181:	learn: 0.1164087	total: 1.09s	remaining: 1.91s
# 182:	learn: 0.1163678	total: 1.1s	remaining: 1.9s
# 183:	learn: 0.1163395	total: 1.1s	remaining: 1.9s
# 184:	learn: 0.1162607	total: 1.11s	remaining: 1.89s
# 185:	learn: 0.1162039	total: 1.12s	remaining: 1.88s
# 186:	learn: 0.1161631	total: 1.12s	remaining: 1.88s
# 187:	learn: 0.1161334	total: 1.13s	remaining: 1.87s
# 188:	learn: 0.1160954	total: 1.13s	remaining: 1.86s
# 189:	learn: 0.1160636	total: 1.14s	remaining: 1.86s
# 190:	learn: 0.1160200	total: 1.15s	remaining: 1.85s
# 191:	learn: 0.1159835	total: 1.15s	remaining: 1.85s
# 192:	learn: 0.1159522	total: 1.16s	remaining: 1.84s
# 193:	learn: 0.1159163	total: 1.16s	remaining: 1.83s
# 194:	learn: 0.1158838	total: 1.17s	remaining: 1.83s
# 195:	learn: 0.1158371	total: 1.18s	remaining: 1.82s
# 196:	learn: 0.1158147	total: 1.18s	remaining: 1.82s
# 197:	learn: 0.1157910	total: 1.19s	remaining: 1.81s
# 198:	learn: 0.1157356	total: 1.19s	remaining: 1.8s
# 199:	learn: 0.1157042	total: 1.2s	remaining: 1.8s
# 200:	learn: 0.1156632	total: 1.2s	remaining: 1.79s
# 201:	learn: 0.1156272	total: 1.21s	remaining: 1.78s
# 202:	learn: 0.1155925	total: 1.22s	remaining: 1.78s
# 203:	learn: 0.1155637	total: 1.22s	remaining: 1.77s
# 204:	learn: 0.1155161	total: 1.23s	remaining: 1.76s
# 205:	learn: 0.1154877	total: 1.23s	remaining: 1.76s
# 206:	learn: 0.1154601	total: 1.24s	remaining: 1.75s
# 207:	learn: 0.1154290	total: 1.24s	remaining: 1.75s
# 208:	learn: 0.1153902	total: 1.25s	remaining: 1.74s
# 209:	learn: 0.1153525	total: 1.25s	remaining: 1.73s
# 210:	learn: 0.1153288	total: 1.26s	remaining: 1.73s
# 211:	learn: 0.1153119	total: 1.27s	remaining: 1.72s
# 212:	learn: 0.1152835	total: 1.27s	remaining: 1.72s
# 213:	learn: 0.1152582	total: 1.28s	remaining: 1.71s
# 214:	learn: 0.1152335	total: 1.29s	remaining: 1.7s
# 215:	learn: 0.1152180	total: 1.29s	remaining: 1.7s
# 216:	learn: 0.1151910	total: 1.3s	remaining: 1.69s
# 217:	learn: 0.1151666	total: 1.3s	remaining: 1.69s
# 218:	learn: 0.1151361	total: 1.31s	remaining: 1.68s
# 219:	learn: 0.1151192	total: 1.31s	remaining: 1.67s
# 220:	learn: 0.1150789	total: 1.32s	remaining: 1.67s
# 221:	learn: 0.1150571	total: 1.33s	remaining: 1.66s
# 222:	learn: 0.1150216	total: 1.33s	remaining: 1.66s
# 223:	learn: 0.1149446	total: 1.34s	remaining: 1.65s
# 224:	learn: 0.1148787	total: 1.35s	remaining: 1.65s
# 225:	learn: 0.1148531	total: 1.35s	remaining: 1.64s
# 226:	learn: 0.1148295	total: 1.36s	remaining: 1.64s
# 227:	learn: 0.1147999	total: 1.37s	remaining: 1.63s
# 228:	learn: 0.1147744	total: 1.37s	remaining: 1.63s
# 229:	learn: 0.1147341	total: 1.38s	remaining: 1.62s
# 230:	learn: 0.1146966	total: 1.39s	remaining: 1.61s
# 231:	learn: 0.1146616	total: 1.39s	remaining: 1.61s
# 232:	learn: 0.1146003	total: 1.4s	remaining: 1.6s
# 233:	learn: 0.1145553	total: 1.4s	remaining: 1.6s
# 234:	learn: 0.1145294	total: 1.41s	remaining: 1.59s
# 235:	learn: 0.1145078	total: 1.42s	remaining: 1.58s
# 236:	learn: 0.1144777	total: 1.42s	remaining: 1.58s
# 237:	learn: 0.1144305	total: 1.43s	remaining: 1.57s
# 238:	learn: 0.1144179	total: 1.43s	remaining: 1.57s
# 239:	learn: 0.1143756	total: 1.44s	remaining: 1.56s
# 240:	learn: 0.1143495	total: 1.45s	remaining: 1.55s
# 241:	learn: 0.1143282	total: 1.45s	remaining: 1.55s
# 242:	learn: 0.1142994	total: 1.46s	remaining: 1.54s
# 243:	learn: 0.1142838	total: 1.47s	remaining: 1.54s
# 244:	learn: 0.1142624	total: 1.47s	remaining: 1.53s
# 245:	learn: 0.1142120	total: 1.48s	remaining: 1.53s
# 246:	learn: 0.1141795	total: 1.49s	remaining: 1.52s
# 247:	learn: 0.1141585	total: 1.49s	remaining: 1.52s
# 248:	learn: 0.1141458	total: 1.5s	remaining: 1.51s
# 249:	learn: 0.1141276	total: 1.5s	remaining: 1.5s
# 250:	learn: 0.1140842	total: 1.51s	remaining: 1.5s
# 251:	learn: 0.1140524	total: 1.52s	remaining: 1.49s
# 252:	learn: 0.1140319	total: 1.52s	remaining: 1.49s
# 253:	learn: 0.1139936	total: 1.53s	remaining: 1.48s
# 254:	learn: 0.1139662	total: 1.54s	remaining: 1.48s
# 255:	learn: 0.1139412	total: 1.55s	remaining: 1.47s
# 256:	learn: 0.1139217	total: 1.55s	remaining: 1.47s
# 257:	learn: 0.1138829	total: 1.56s	remaining: 1.46s
# 258:	learn: 0.1138508	total: 1.57s	remaining: 1.46s
# 259:	learn: 0.1138279	total: 1.57s	remaining: 1.45s
# 260:	learn: 0.1137937	total: 1.58s	remaining: 1.45s
# 261:	learn: 0.1137625	total: 1.59s	remaining: 1.44s
# 262:	learn: 0.1137446	total: 1.59s	remaining: 1.44s
# 263:	learn: 0.1137254	total: 1.6s	remaining: 1.43s
# 264:	learn: 0.1137024	total: 1.6s	remaining: 1.42s
# 265:	learn: 0.1136922	total: 1.61s	remaining: 1.42s
# 266:	learn: 0.1136772	total: 1.62s	remaining: 1.41s
# 267:	learn: 0.1136608	total: 1.62s	remaining: 1.41s
# 268:	learn: 0.1136261	total: 1.63s	remaining: 1.4s
# 269:	learn: 0.1136141	total: 1.64s	remaining: 1.4s
# 270:	learn: 0.1135993	total: 1.65s	remaining: 1.39s
# 271:	learn: 0.1135346	total: 1.65s	remaining: 1.39s
# 272:	learn: 0.1135193	total: 1.66s	remaining: 1.38s
# 273:	learn: 0.1135007	total: 1.67s	remaining: 1.38s
# 274:	learn: 0.1134691	total: 1.67s	remaining: 1.37s
# 275:	learn: 0.1134538	total: 1.68s	remaining: 1.36s
# 276:	learn: 0.1134278	total: 1.69s	remaining: 1.36s
# 277:	learn: 0.1133997	total: 1.7s	remaining: 1.35s
# 278:	learn: 0.1133806	total: 1.7s	remaining: 1.35s
# 279:	learn: 0.1133399	total: 1.71s	remaining: 1.34s
# 280:	learn: 0.1133140	total: 1.71s	remaining: 1.33s
# 281:	learn: 0.1132874	total: 1.72s	remaining: 1.33s
# 282:	learn: 0.1132618	total: 1.73s	remaining: 1.32s
# 283:	learn: 0.1132389	total: 1.73s	remaining: 1.32s
# 284:	learn: 0.1132171	total: 1.74s	remaining: 1.31s
# 285:	learn: 0.1131979	total: 1.74s	remaining: 1.3s
# 286:	learn: 0.1131644	total: 1.75s	remaining: 1.3s
# 287:	learn: 0.1131365	total: 1.76s	remaining: 1.29s
# 288:	learn: 0.1131066	total: 1.76s	remaining: 1.29s
# 289:	learn: 0.1130810	total: 1.77s	remaining: 1.28s
# 290:	learn: 0.1130685	total: 1.77s	remaining: 1.27s
# 291:	learn: 0.1130490	total: 1.78s	remaining: 1.27s
# 292:	learn: 0.1130312	total: 1.79s	remaining: 1.26s
# 293:	learn: 0.1130064	total: 1.79s	remaining: 1.26s
# 294:	learn: 0.1129717	total: 1.8s	remaining: 1.25s
# 295:	learn: 0.1129537	total: 1.81s	remaining: 1.24s
# 296:	learn: 0.1129398	total: 1.81s	remaining: 1.24s
# 297:	learn: 0.1128834	total: 1.82s	remaining: 1.23s
# 298:	learn: 0.1128659	total: 1.82s	remaining: 1.23s
# 299:	learn: 0.1128425	total: 1.83s	remaining: 1.22s
# 300:	learn: 0.1128167	total: 1.84s	remaining: 1.21s
# 301:	learn: 0.1128017	total: 1.84s	remaining: 1.21s
# 302:	learn: 0.1127775	total: 1.85s	remaining: 1.2s
# 303:	learn: 0.1127592	total: 1.86s	remaining: 1.2s
# 304:	learn: 0.1127253	total: 1.86s	remaining: 1.19s
# 305:	learn: 0.1127006	total: 1.87s	remaining: 1.19s
# 306:	learn: 0.1126733	total: 1.88s	remaining: 1.18s
# 307:	learn: 0.1126564	total: 1.88s	remaining: 1.17s
# 308:	learn: 0.1126241	total: 1.89s	remaining: 1.17s
# 309:	learn: 0.1125951	total: 1.89s	remaining: 1.16s
# 310:	learn: 0.1125617	total: 1.9s	remaining: 1.15s
# 90:	learn: 0.1310324	total: 556ms	remaining: 5.56s
# 91:	learn: 0.1308640	total: 562ms	remaining: 5.55s
# 92:	learn: 0.1306839	total: 568ms	remaining: 5.54s
# 93:	learn: 0.1304435	total: 574ms	remaining: 5.53s
# 94:	learn: 0.1301745	total: 580ms	remaining: 5.53s
# 95:	learn: 0.1300533	total: 587ms	remaining: 5.53s
# 96:	learn: 0.1298037	total: 593ms	remaining: 5.52s
# 97:	learn: 0.1296424	total: 599ms	remaining: 5.52s
# 98:	learn: 0.1294409	total: 605ms	remaining: 5.51s
# 99:	learn: 0.1292976	total: 611ms	remaining: 5.5s
# 100:	learn: 0.1291748	total: 617ms	remaining: 5.5s
# 101:	learn: 0.1289690	total: 623ms	remaining: 5.49s
# 102:	learn: 0.1288570	total: 629ms	remaining: 5.48s
# 103:	learn: 0.1287106	total: 635ms	remaining: 5.47s
# 104:	learn: 0.1285600	total: 641ms	remaining: 5.46s
# 105:	learn: 0.1284517	total: 647ms	remaining: 5.46s
# 106:	learn: 0.1282618	total: 653ms	remaining: 5.45s
# 107:	learn: 0.1281195	total: 659ms	remaining: 5.44s
# 108:	learn: 0.1280121	total: 665ms	remaining: 5.43s
# 109:	learn: 0.1278854	total: 671ms	remaining: 5.43s
# 110:	learn: 0.1278142	total: 677ms	remaining: 5.42s
# 111:	learn: 0.1276654	total: 683ms	remaining: 5.42s
# 112:	learn: 0.1275568	total: 689ms	remaining: 5.41s
# 113:	learn: 0.1273783	total: 695ms	remaining: 5.4s
# 114:	learn: 0.1272160	total: 701ms	remaining: 5.39s
# 115:	learn: 0.1271182	total: 707ms	remaining: 5.39s
# 116:	learn: 0.1270183	total: 713ms	remaining: 5.38s
# 117:	learn: 0.1268774	total: 719ms	remaining: 5.37s
# 118:	learn: 0.1267772	total: 726ms	remaining: 5.37s
# 119:	learn: 0.1266400	total: 733ms	remaining: 5.38s
# 120:	learn: 0.1265061	total: 739ms	remaining: 5.37s
# 121:	learn: 0.1263571	total: 746ms	remaining: 5.37s
# 122:	learn: 0.1262512	total: 752ms	remaining: 5.36s
# 123:	learn: 0.1261685	total: 758ms	remaining: 5.35s
# 124:	learn: 0.1260294	total: 764ms	remaining: 5.34s
# 125:	learn: 0.1259404	total: 770ms	remaining: 5.34s
# 126:	learn: 0.1257925	total: 776ms	remaining: 5.33s
# 127:	learn: 0.1257134	total: 782ms	remaining: 5.33s
# 128:	learn: 0.1256164	total: 788ms	remaining: 5.32s
# 129:	learn: 0.1255132	total: 794ms	remaining: 5.32s
# 130:	learn: 0.1254095	total: 801ms	remaining: 5.31s
# 131:	learn: 0.1253261	total: 807ms	remaining: 5.3s
# 132:	learn: 0.1252385	total: 813ms	remaining: 5.3s
# 133:	learn: 0.1251238	total: 819ms	remaining: 5.29s
# 134:	learn: 0.1250469	total: 825ms	remaining: 5.29s
# 135:	learn: 0.1249876	total: 831ms	remaining: 5.28s
# 136:	learn: 0.1249229	total: 838ms	remaining: 5.28s
# 137:	learn: 0.1248592	total: 843ms	remaining: 5.27s
# 138:	learn: 0.1247512	total: 849ms	remaining: 5.26s
# 139:	learn: 0.1246458	total: 855ms	remaining: 5.25s
# 140:	learn: 0.1245386	total: 861ms	remaining: 5.25s
# 141:	learn: 0.1244481	total: 868ms	remaining: 5.24s
# 142:	learn: 0.1243811	total: 874ms	remaining: 5.24s
# 143:	learn: 0.1242760	total: 879ms	remaining: 5.23s
# 144:	learn: 0.1242004	total: 886ms	remaining: 5.22s
# 145:	learn: 0.1241384	total: 892ms	remaining: 5.22s
# 146:	learn: 0.1240474	total: 898ms	remaining: 5.21s
# 147:	learn: 0.1239824	total: 904ms	remaining: 5.2s
# 148:	learn: 0.1238960	total: 910ms	remaining: 5.2s
# 149:	learn: 0.1238231	total: 917ms	remaining: 5.19s
# 150:	learn: 0.1237476	total: 923ms	remaining: 5.19s
# 151:	learn: 0.1236883	total: 931ms	remaining: 5.19s
# 152:	learn: 0.1236158	total: 937ms	remaining: 5.18s
# 153:	learn: 0.1235237	total: 943ms	remaining: 5.18s
# 154:	learn: 0.1234523	total: 949ms	remaining: 5.17s
# 155:	learn: 0.1233863	total: 955ms	remaining: 5.17s
# 156:	learn: 0.1233194	total: 961ms	remaining: 5.16s
# 157:	learn: 0.1232671	total: 967ms	remaining: 5.16s
# 158:	learn: 0.1231896	total: 973ms	remaining: 5.15s
# 159:	learn: 0.1231175	total: 980ms	remaining: 5.14s
# 160:	learn: 0.1230257	total: 986ms	remaining: 5.14s
# 161:	learn: 0.1229717	total: 992ms	remaining: 5.13s
# 162:	learn: 0.1229020	total: 998ms	remaining: 5.13s
# 163:	learn: 0.1228194	total: 1s	remaining: 5.12s
# 164:	learn: 0.1227590	total: 1.01s	remaining: 5.11s
# 165:	learn: 0.1226897	total: 1.02s	remaining: 5.11s
# 166:	learn: 0.1226469	total: 1.02s	remaining: 5.1s
# 167:	learn: 0.1225778	total: 1.03s	remaining: 5.09s
# 168:	learn: 0.1225291	total: 1.03s	remaining: 5.08s
# 169:	learn: 0.1224725	total: 1.04s	remaining: 5.08s
# 170:	learn: 0.1224190	total: 1.05s	remaining: 5.07s
# 171:	learn: 0.1223476	total: 1.05s	remaining: 5.07s
# 172:	learn: 0.1222913	total: 1.06s	remaining: 5.06s
# 173:	learn: 0.1222299	total: 1.06s	remaining: 5.06s
# 174:	learn: 0.1221616	total: 1.07s	remaining: 5.05s
# 175:	learn: 0.1221007	total: 1.08s	remaining: 5.04s
# 176:	learn: 0.1220391	total: 1.08s	remaining: 5.04s
# 177:	learn: 0.1219761	total: 1.09s	remaining: 5.03s
# 178:	learn: 0.1219050	total: 1.09s	remaining: 5.02s
# 179:	learn: 0.1218389	total: 1.1s	remaining: 5.02s
# 180:	learn: 0.1217958	total: 1.11s	remaining: 5.01s
# 181:	learn: 0.1217502	total: 1.11s	remaining: 5s
# 182:	learn: 0.1217045	total: 1.12s	remaining: 5s
# 183:	learn: 0.1216640	total: 1.13s	remaining: 4.99s
# 184:	learn: 0.1216120	total: 1.13s	remaining: 4.99s
# 185:	learn: 0.1215498	total: 1.14s	remaining: 4.99s
# 186:	learn: 0.1214814	total: 1.15s	remaining: 4.99s
# 187:	learn: 0.1214281	total: 1.15s	remaining: 4.98s
# 188:	learn: 0.1213924	total: 1.16s	remaining: 4.97s
# 189:	learn: 0.1213483	total: 1.16s	remaining: 4.97s
# 190:	learn: 0.1212944	total: 1.17s	remaining: 4.96s
# 191:	learn: 0.1212531	total: 1.18s	remaining: 4.95s
# 192:	learn: 0.1211977	total: 1.18s	remaining: 4.95s
# 193:	learn: 0.1211457	total: 1.19s	remaining: 4.94s
# 194:	learn: 0.1211023	total: 1.2s	remaining: 4.93s
# 195:	learn: 0.1210797	total: 1.2s	remaining: 4.93s
# 196:	learn: 0.1210513	total: 1.21s	remaining: 4.92s
# 197:	learn: 0.1209942	total: 1.21s	remaining: 4.91s
# 198:	learn: 0.1209466	total: 1.22s	remaining: 4.91s
# 199:	learn: 0.1208968	total: 1.22s	remaining: 4.9s
# 200:	learn: 0.1208411	total: 1.23s	remaining: 4.89s
# 201:	learn: 0.1207824	total: 1.24s	remaining: 4.89s
# 202:	learn: 0.1207465	total: 1.24s	remaining: 4.88s
# 203:	learn: 0.1207057	total: 1.25s	remaining: 4.88s
# 204:	learn: 0.1206694	total: 1.25s	remaining: 4.87s
# 205:	learn: 0.1206388	total: 1.26s	remaining: 4.86s
# 206:	learn: 0.1205966	total: 1.27s	remaining: 4.86s
# 207:	learn: 0.1205500	total: 1.27s	remaining: 4.85s
# 208:	learn: 0.1205147	total: 1.28s	remaining: 4.84s
# 209:	learn: 0.1204826	total: 1.28s	remaining: 4.84s
# 210:	learn: 0.1204433	total: 1.29s	remaining: 4.83s
# 211:	learn: 0.1204093	total: 1.3s	remaining: 4.83s
# 212:	learn: 0.1203750	total: 1.3s	remaining: 4.82s
# 213:	learn: 0.1203325	total: 1.31s	remaining: 4.81s
# 214:	learn: 0.1203007	total: 1.32s	remaining: 4.81s
# 215:	learn: 0.1202611	total: 1.32s	remaining: 4.8s
# 216:	learn: 0.1202125	total: 1.33s	remaining: 4.79s
# 217:	learn: 0.1201691	total: 1.34s	remaining: 4.8s
# 218:	learn: 0.1201277	total: 1.34s	remaining: 4.79s
# 219:	learn: 0.1200451	total: 1.35s	remaining: 4.79s
# 220:	learn: 0.1199984	total: 1.35s	remaining: 4.78s
# 221:	learn: 0.1199622	total: 1.36s	remaining: 4.77s
# 222:	learn: 0.1198965	total: 1.37s	remaining: 4.77s
# 223:	learn: 0.1198543	total: 1.37s	remaining: 4.76s
# 224:	learn: 0.1197798	total: 1.38s	remaining: 4.75s
# 225:	learn: 0.1197484	total: 1.39s	remaining: 4.75s
# 226:	learn: 0.1197121	total: 1.39s	remaining: 4.74s
# 227:	learn: 0.1196863	total: 1.4s	remaining: 4.73s
# 228:	learn: 0.1196539	total: 1.4s	remaining: 4.73s
# 229:	learn: 0.1196195	total: 1.41s	remaining: 4.72s
# 1730:	learn: 0.1086551	total: 12.3s	remaining: 1.9s
# 1731:	learn: 0.1086502	total: 12.3s	remaining: 1.9s
# 1732:	learn: 0.1086469	total: 12.3s	remaining: 1.89s
# 1733:	learn: 0.1086438	total: 12.3s	remaining: 1.88s
# 1734:	learn: 0.1086378	total: 12.3s	remaining: 1.88s
# 1735:	learn: 0.1086330	total: 12.3s	remaining: 1.87s
# 1736:	learn: 0.1086245	total: 12.3s	remaining: 1.86s
# 1737:	learn: 0.1086206	total: 12.3s	remaining: 1.85s
# 1738:	learn: 0.1086146	total: 12.3s	remaining: 1.85s
# 1739:	learn: 0.1086118	total: 12.3s	remaining: 1.84s
# 1740:	learn: 0.1086076	total: 12.3s	remaining: 1.83s
# 1741:	learn: 0.1086043	total: 12.3s	remaining: 1.83s
# 1742:	learn: 0.1085933	total: 12.3s	remaining: 1.82s
# 1743:	learn: 0.1085868	total: 12.4s	remaining: 1.81s
# 1744:	learn: 0.1085831	total: 12.4s	remaining: 1.81s
# 1745:	learn: 0.1085794	total: 12.4s	remaining: 1.8s
# 1746:	learn: 0.1085742	total: 12.4s	remaining: 1.79s
# 1747:	learn: 0.1085702	total: 12.4s	remaining: 1.78s
# 1748:	learn: 0.1085662	total: 12.4s	remaining: 1.78s
# 1749:	learn: 0.1085618	total: 12.4s	remaining: 1.77s
# 1750:	learn: 0.1085563	total: 12.4s	remaining: 1.76s
# 1751:	learn: 0.1085506	total: 12.4s	remaining: 1.76s
# 1752:	learn: 0.1085404	total: 12.4s	remaining: 1.75s
# 1753:	learn: 0.1085333	total: 12.4s	remaining: 1.74s
# 1754:	learn: 0.1085287	total: 12.4s	remaining: 1.74s
# 1755:	learn: 0.1085248	total: 12.4s	remaining: 1.73s
# 1756:	learn: 0.1085202	total: 12.5s	remaining: 1.72s
# 1757:	learn: 0.1085163	total: 12.5s	remaining: 1.72s
# 1758:	learn: 0.1085098	total: 12.5s	remaining: 1.71s
# 1759:	learn: 0.1085038	total: 12.5s	remaining: 1.7s
# 1760:	learn: 0.1084999	total: 12.5s	remaining: 1.69s
# 1761:	learn: 0.1084964	total: 12.5s	remaining: 1.69s
# 1762:	learn: 0.1084902	total: 12.5s	remaining: 1.68s
# 1763:	learn: 0.1084848	total: 12.5s	remaining: 1.67s
# 1764:	learn: 0.1084813	total: 12.5s	remaining: 1.67s
# 1765:	learn: 0.1084775	total: 12.5s	remaining: 1.66s
# 1766:	learn: 0.1084726	total: 12.5s	remaining: 1.65s
# 1767:	learn: 0.1084686	total: 12.5s	remaining: 1.65s
# 1768:	learn: 0.1084648	total: 12.6s	remaining: 1.64s
# 1769:	learn: 0.1084594	total: 12.6s	remaining: 1.63s
# 1770:	learn: 0.1084579	total: 12.6s	remaining: 1.62s
# 1771:	learn: 0.1084547	total: 12.6s	remaining: 1.62s
# 1772:	learn: 0.1084461	total: 12.6s	remaining: 1.61s
# 1773:	learn: 0.1084438	total: 12.6s	remaining: 1.6s
# 1774:	learn: 0.1084387	total: 12.6s	remaining: 1.6s
# 1775:	learn: 0.1084359	total: 12.6s	remaining: 1.59s
# 1776:	learn: 0.1084305	total: 12.6s	remaining: 1.58s
# 1777:	learn: 0.1084278	total: 12.6s	remaining: 1.57s
# 1778:	learn: 0.1084251	total: 12.6s	remaining: 1.57s
# 1779:	learn: 0.1084208	total: 12.6s	remaining: 1.56s
# 1780:	learn: 0.1084184	total: 12.6s	remaining: 1.55s
# 1781:	learn: 0.1084127	total: 12.7s	remaining: 1.55s
# 1782:	learn: 0.1084076	total: 12.7s	remaining: 1.54s
# 1783:	learn: 0.1084040	total: 12.7s	remaining: 1.53s
# 1784:	learn: 0.1084017	total: 12.7s	remaining: 1.53s
# 1785:	learn: 0.1083963	total: 12.7s	remaining: 1.52s
# 1786:	learn: 0.1083790	total: 12.7s	remaining: 1.51s
# 1787:	learn: 0.1083734	total: 12.7s	remaining: 1.5s
# 1788:	learn: 0.1083704	total: 12.7s	remaining: 1.5s
# 1789:	learn: 0.1083673	total: 12.7s	remaining: 1.49s
# 1790:	learn: 0.1083632	total: 12.7s	remaining: 1.48s
# 1791:	learn: 0.1083571	total: 12.7s	remaining: 1.48s
# 1792:	learn: 0.1083537	total: 12.7s	remaining: 1.47s
# 1793:	learn: 0.1083505	total: 12.7s	remaining: 1.46s
# 1794:	learn: 0.1083444	total: 12.8s	remaining: 1.46s
# 1795:	learn: 0.1083389	total: 12.8s	remaining: 1.45s
# 1796:	learn: 0.1083316	total: 12.8s	remaining: 1.44s
# 1797:	learn: 0.1083266	total: 12.8s	remaining: 1.44s
# 1798:	learn: 0.1083215	total: 12.8s	remaining: 1.43s
# 1799:	learn: 0.1083157	total: 12.8s	remaining: 1.42s
# 1800:	learn: 0.1083106	total: 12.8s	remaining: 1.41s
# 1801:	learn: 0.1083052	total: 12.8s	remaining: 1.41s
# 1802:	learn: 0.1083012	total: 12.8s	remaining: 1.4s
# 1803:	learn: 0.1082961	total: 12.8s	remaining: 1.39s
# 1804:	learn: 0.1082923	total: 12.8s	remaining: 1.39s
# 1805:	learn: 0.1082891	total: 12.8s	remaining: 1.38s
# 1806:	learn: 0.1082806	total: 12.8s	remaining: 1.37s
# 1807:	learn: 0.1082772	total: 12.9s	remaining: 1.36s
# 1808:	learn: 0.1082731	total: 12.9s	remaining: 1.36s
# 1809:	learn: 0.1082680	total: 12.9s	remaining: 1.35s
# 1810:	learn: 0.1082639	total: 12.9s	remaining: 1.34s
# 1811:	learn: 0.1082553	total: 12.9s	remaining: 1.34s
# 1812:	learn: 0.1082465	total: 12.9s	remaining: 1.33s
# 1813:	learn: 0.1082418	total: 12.9s	remaining: 1.32s
# 1814:	learn: 0.1082379	total: 12.9s	remaining: 1.32s
# 1815:	learn: 0.1082324	total: 12.9s	remaining: 1.31s
# 1816:	learn: 0.1082298	total: 12.9s	remaining: 1.3s
# 1817:	learn: 0.1082265	total: 12.9s	remaining: 1.29s
# 1818:	learn: 0.1082228	total: 12.9s	remaining: 1.29s
